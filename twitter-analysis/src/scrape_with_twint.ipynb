# %% [markdown]
# ### Milans experiments with the Twitter API for Berliner Luft project

# %% [markdown]
# ### Import dependencies

# %%
import sys
# !{sys.executable} -m pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# !conda install -c anaconda pandas -y
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /private/var/folders/h1/504cfn3s3ms5wlqq5zvg_b1r0000gn/T/pip-install-rcw4rrjp/twint_84b24ae992a64433994e78cb90e27723
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
# ...
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=38760 sha256=e4ac3029080510b7d46b449c39c3a47500024a71ef61be034d41de0904272416
#   Stored in directory: /private/var/folders/h1/504cfn3s3ms5wlqq5zvg_b1r0000gn/T/pip-ephem-wheel-cache-lh0wz95h/wheels/c9/d4/7d/fb0732852f335c92c52450e5c86b6ba5fb09fa226f3584db34
# Successfully built twint
# ...
#   Attempting uninstall: twint
#     Found existing installation: twint 2.1.20
#     Uninstalling twint-2.1.20:
#       Successfully uninstalled twint-2.1.20
#   WARNING: The script twint is installed in '/Users/palermo/.local/bin' which is not on PATH.
# ...

# %%
import twint
import pandas as pd

# Patches asyncio to allow the running of multiple event loops in Jupyter Notebooks.
# Fixes: "RuntimeError: This event loop is already running"
import nest_asyncio

nest_asyncio.apply()

# %%
c = twint.Config()

c.Search = '#friedrichstraße', '#friedrichstrasse'
c.Since = '2020-06-01'
c.Store_csv = True
c.Output = 'tweets/tweets.csv'

twint.run.Search(c)
# Out:
# 1345749844049219585 2021-01-03 16:12:20 +0100 <SBahnBerlin> #S1, #S2, #S25: Auf Grund einer Signalstörung zw. #Oranienburger_Str. &lt;&gt; #Friedrichstraße kommt es in Richtung Süden zu Verspätungen.
# 1345328822149935122 2021-01-02 12:19:20 +0100 <eff_kah> #Friedrichstraße - #Neißetal - #Königshain - #LausitzerSeenland  https://t.co/4K8H5WOLcW
# 1344711173044908034 2020-12-31 19:25:01 +0100 <SBahnBerlin> #S3 #S5 #S7 #S75 #S9 die polizeilichen Ermittlungen zwischen #Friedrichstraße und #Tiergarten sind beendet, der S-Bahnverkehr wird wieder nach Fahrplan aufgenommen. In der Folge noch mit Verspätungen und Ausfällen rechnen.
# 1344708942925099010 2020-12-31 19:16:10 +0100 <SBahnBerlin> #S9 verkehrt zwischen #BER_T1 und #Friedrichstraße sowie zwischen #Tiergarten und #Spandau:  https://t.co/6DzmAfcCTJ
# ...

# %%
data = pd.read_csv('tweets/tweets.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-0e550814fedc> in <module>()
# ----> 1 data = pd.read_csv('../tweets/tweets.csv')
#       2 data.head()
#
# /Applications/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
